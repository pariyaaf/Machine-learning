# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# Classification knn model
#     </font>
# </h1>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import f1_score

# %%
train_data = pd.read_csv('data/train.csv')
train_data.head(2)
# Out:
#     AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0  73107   1161.807    442.4074    217.7261        0.8705  305.0946    0.9424
# 1  89272   1173.181    460.2551    251.9546        0.8369  337.1419    0.9641
#
#    CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  SHAPEFACTOR_1  \
# 0        77579  0.7710        2.0319     0.6806       0.6896         0.0061
# 1        92598  0.7584        1.8267     0.8151       0.7325         0.0052
#
#    SHAPEFACTOR_2  SHAPEFACTOR_3  SHAPEFACTOR_4              Class
# 0         0.0030         0.4756         0.9664  Kirmizi_Pistachio
# 1         0.0028         0.5366         0.9802     Siit_Pistachio

# %%
test_data = pd.read_csv('data/test.csv')
test_data.head(2)
# Out:
#     AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0  97328  1828.9189    468.0632    273.5379        0.8115  352.0254    0.9413
# 1  99449  1200.6021    456.6979    279.8051        0.7903  355.8404    0.9803
#
#    CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  SHAPEFACTOR_1  \
# 0       103392  0.7235        1.7111     0.3656       0.7521         0.0048
# 1       101447  0.7192        1.6322     0.8670       0.7792         0.0046
#
#    SHAPEFACTOR_2  SHAPEFACTOR_3  SHAPEFACTOR_4
# 0         0.0028         0.5656         0.9679
# 1         0.0028         0.6071         0.9909

# %%
label = train_data['Class']
train_data.drop(columns=['Class'], inplace=True)

# %%
train_data.head(1)
# Out:
#     AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0  73107   1161.807    442.4074    217.7261        0.8705  305.0946    0.9424
#
#    CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  SHAPEFACTOR_1  \
# 0        77579   0.771        2.0319     0.6806       0.6896         0.0061
#
#    SHAPEFACTOR_2  SHAPEFACTOR_3  SHAPEFACTOR_4
# 0          0.003         0.4756         0.9664

# %%
scaler = MinMaxScaler()

train_scaler = scaler.fit_transform(train_data)
test_scaler = scaler.transform(test_data)

# %%
train_scaler
# Out:
# array([[0.45964968, 0.15998641, 0.56476409, ..., 0.20689655, 0.47025496,
#         0.91389329],
#        [0.63125265, 0.16598319, 0.64808019, ..., 0.13793103, 0.58545798,
#         0.95034337],
#        [0.33064756, 0.07456479, 0.30576141, ..., 0.34482759, 0.55108593,
#         0.89461173],
#        ...,
#        [0.64184713, 0.27003678, 0.50200615, ..., 0.20689655, 0.7516525 ,
#         0.98415214],
#        [0.46008493, 0.23803623, 0.68913208, ..., 0.13793103, 0.37148253,
#         0.879028  ],
#        [0.51987261, 0.2459659 , 0.60763236, ..., 0.20689655, 0.50103872,
#         0.81299525]])

# %%
X_train, X_val, y_train, y_val = train_test_split(train_scaler, label,  test_size=0.33, random_state=42)

# %%
model = KNeighborsClassifier(n_neighbors=5, p=2, weights='distance')

model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(weights='distance')

# %%
val_pred = model.predict(X_val)
prediction = f1_score(y_val, val_pred, average='weighted')

prediction
# Out:
# 0.857031209224115

# %%
prediction = model.predict(test_scaler)

prediction = pd.DataFrame(prediction, columns=["Class"])

prediction
# Out:
#                  Class
# 0       Siit_Pistachio
# 1       Siit_Pistachio
# 2       Siit_Pistachio
# 3       Siit_Pistachio
# 4    Kirmizi_Pistachio
# ..                 ...
# 425     Siit_Pistachio
# 426     Siit_Pistachio
# 427     Siit_Pistachio
# 428  Kirmizi_Pistachio
# 429  Kirmizi_Pistachio
#
# [430 rows x 1 columns]

# %%
print(prediction[:5])
# Out:
#                Class
# 0     Siit_Pistachio
# 1     Siit_Pistachio
# 2     Siit_Pistachio
# 3     Siit_Pistachio
# 4  Kirmizi_Pistachio
